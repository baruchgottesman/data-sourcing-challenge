# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# I'm adding this url parse because the field_query seems to be breaking the url and this may fix it
import urllib.parse

# I had to add this to help with the reorganization of the dataframe into a proper chart
import re

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
encoded_filter_query = urllib.parse.quote(query)
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"
begin_date = "20130101"
end_date = "20230531"

sort = "newest"


query_url = f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}&fl={field_list}&fq={encoded_filter_query}&sort={sort}"
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=0Ynj9P6CZNRvyd9EWKoByLOXWX1o2Wp2&begin_date=20130101&end_date=20230531&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count&fq=section_name%3A%22Movies%22%20AND%20type_of_material%3A%22Review%22%20AND%20headline%3A%22love%22&sort=newest'

# %%
# Create an empty list to store the reviews
NYT_Reviews_List = []

# loop through pages 0-19
for page in range(20):
    
    # create query with a page number
    query_url = f"{query_url}&page{page}"
    
# API results show 10 articles at a time
    response = requests.get(query_url)
    data = response.json()
    
    # Make a "GET" request and retrieve the JSON

    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        if 'response' in data and 'docs' in data['response']:
            for article in data['response']['docs']: 
                NYT_Reviews_List.append(article)
            print(f"Retrieved page {page}")
        else:
            print(f"No results found on page {page}")
            break
    except Keyerror as e:
        print(f"Error on page {page}: {str(e)}")
        break

        # loop through the reviews["response"]["docs"] and append each review to the list

        # Print the page that was just retrieved


        # Print the page number that had no results then break from the loop
# Out:
# Retrieved page 0
# Retrieved page 1
# Retrieved page 2
# Retrieved page 3
# Retrieved page 4
# Retrieved page 5
# Retrieved page 6
# Retrieved page 7
# Retrieved page 8
# Retrieved page 9
# Retrieved page 10
# Retrieved page 11
# Retrieved page 12
# Retrieved page 13
# Retrieved page 14
# Retrieved page 15
# Retrieved page 16
# Retrieved page 17
# Retrieved page 18
# Retrieved page 19

# %%
response = requests.get(NYT_query_url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [], 'meta': {'hits': 0, 'offset': 0, 'time': 219}}}

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
NYT_dataframe = pd.json_normalize(NYT_Reviews_List)
NYT_dataframe
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"

NYT_dataframe['title'] = df['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])

NYT_dataframe
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 One True Loves
# 196                 The Lost Weekend: A Love Story
# 197                             A Thousand and One
# 198                             Your Place or Mine
# 199                   Love in the Time of Fentanyl
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keywords):
    if isinstance(keywords, list) and all(isinstance(d, dict) for d in keywords):
        return ', '.join([keyword['value'] for keyword in keywords])
    elif isinstance(keywords, str):
        return keywords
    return ''
    # Apply the extract_keywords function to the "keywords" column
NYT_dataframe['keywords'] = NYT_dataframe['keywords'].apply(extract_keywords)

# Extract the movie title from the "headline.main" column
NYT_dataframe['title'] = NYT_dataframe['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
NYT_dataframe.head(10)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
# 5  https://www.nytimes.com/2023/04/13/movies/one-...
# 6  https://www.nytimes.com/2023/04/13/movies/the-...
# 7  https://www.nytimes.com/2023/03/30/movies/a-th...
# 8  https://www.nytimes.com/2023/02/09/movies/your...
# 9  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 5  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 6  There’s not much Lennon music heard in this do...  The New York Times
# 7  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 8  This humdrum Netflix romantic comedy features ...  The New York Times
# 9  To combat the overdose crisis, a group that in...  The New York Times
#
#                                             keywords  \
# 0  Movies, The Attachment Diaries (Movie), Diment...
# 1  Movies, Kapur, Shekhar, James, Lily, Azmi, Sha...
# 2  Movies, You Can Live Forever (Movie), Slutsky,...
# 3  Movies, A Tourist's Guide to Love (Movie), Tsu...
# 4  Movies, Zlotowski, Rebecca, Other People's Chi...
# 5  Movies, Bracey, Luke (1989- ), Liu, Simu, Reid...
# 6  Documentary Films and Programs, The Lost Weeke...
# 7  Movies, A Thousand and One (Movie), Rockwell, ...
# 8  Movies, Your Place or Mine (Movie), Witherspoo...
# 9  Documentary Films and Programs, Fentanyl, Drug...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
# 5  2023-04-13T11:00:06+0000         320
# 6  2023-04-13T11:00:03+0000         327
# 7  2023-03-30T18:53:42+0000         971
# 8  2023-02-10T00:00:05+0000         569
# 9  2023-02-02T12:00:11+0000         306
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 5     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 6  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 7  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 8           ‘Your Place or Mine’ Review: Try Neither            None
# 9  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#   headline.content_kicker                  headline.print_headline  \
# 0                    None                   The Attachment Diaries
# 1                    None           What’s Love Got to Do With It?
# 2                    None                     You Can Live Forever
# 3                    None               A Tourist’s  Guide to Love
# 4                    None   Intoxicating Love With a Sobering Turn
# 5                    None                           One True Loves
# 6                    None          The Lost Weekend:  A Love Story
# 7                    None  An Unbending Will Meets a Shifting City
# 8                    None         They Have a Humdrum Kind of Love
# 9                    None             Love in the Time Of Fentanyl
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
# 5          None         None         None             By Brandon Yu
# 6          None         None         None            By Glenn Kenny
# 7          None         None         None         By Manohla Dargis
# 8          None         None         None          By Amy Nicholson
# 9          None         None         None     By Concepción de León
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 5  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 6  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 7  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 8  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 9  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                            title
# 0                         The Attachment Diaries
# 1  What’s Love Got to Do With It?’ Probably a Lo
# 2                           You Can Live Forever
# 3                      A Tourist’s Guide to Love
# 4                        Other People’s Children
# 5                                 One True Loves
# 6                 The Lost Weekend: A Love Story
# 7                             A Thousand and One
# 8                             Your Place or Mine
# 9                   Love in the Time of Fentanyl

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database

Selected_Movie_Titles = NYT_dataframe['title'].to_list()
print(Selected_Movie_Titles[:200])
# Out:
# ['The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Love Got to Do With It?’ Probably a Lo', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'The Attachment Diaries', 'What’s Lov ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results

tmdb_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0

# Loop through the titles
for title in Selected_Movie_Titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
       time.sleep(10)  # Sleep for 10 seconds every 50 requests
 

    # Add 1 to the request counter

    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    try:
        response = requests.get(url + title + tmdb_key_string)
        data = response.json()
        
        if data['results']:
            movie = data['results'][0]
            
            # Get movie id
            movie_id = movie['id']
            
            # Make a request for the full movie details
            movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
            movie_response = requests.get(movie_url)
            movie_data = movie_response.json()
            
            # Extract the genre names into a list
            genres = [genre['name'] for genre in movie_data['genres']]
            
            # Extract the spoken_languages' English name into a list
            languages = [lang['english_name'] for lang in movie_data['spoken_languages']]
            
            # Extract the production_countries' name into a list
            countries = [country['name'] for country in movie_data['production_countries']]
            
            # Add the relevant data to a dictionary and append it to the tmdb_movies_list list
            tmdb_movies_list.append({
                'title': movie['title'],
                'tmdb_id': movie_id,
                'genres': genres,
                'languages': languages,
                'countries': countries,
                'overview': movie['overview'],
                'release_date': movie['release_date'],
                'vote_average': movie['vote_average']
            })
            
            # Print out the title that was found
            print(f"Found: {movie['title']}")
        else:
            print(f"Movie not found: {title}")
    
    except Exception as e:
        print(f"Error processing {title}: {str(e)}")
# Out:
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl
# Found: The Attachment Diaries
# Movie not found: What’s Love Got to Do With It?’ Probably a Lo
# Found: You Can Live Forever
# Found: A Tourist's Guide to Love
# Found: Other People's Children
# Found: One True Loves
# Found: The Lost Weekend: A Love Story
# Found: A Thousand and One
# Found: Your Place or Mine
# Found: Love in the Time of Fentanyl

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
preview = tmdb_movies_list[:5]
formatted_preview = json.dumps(preview, indent=4)
print(formatted_preview)
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "tmdb_id": 743040,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "languages": [
#             "Spanish"
#         ],
#         "countries": [
#             "Argentina"
#         ],
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "release_date": "2021-10-07",
#         "vote_average": 3.0
#     },
#     {
#         "title": "You Can Live Forever",
#         "tmdb_id": 887580,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "languages": [
#             "English",
#             "French"
#         ],
#         "countries": [
#             "Canada",
#             "United States of America"
#         ],
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "release_date": "2023-03-24",
#         "vote_average": 6.474
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "tmdb_id": 813726,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "countries": [
#             "United States of America"
#         ],
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "release_date": "2023-04-21",
#         "vote_average": 6.29
#     },
#     {
#         "title": "Other People's Children",
#         "tmdb_id": 803694,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "languages": [
#             "French",
#             "English"
#         ],
#         "countries": [
#             "France"
#         ],
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "release_date": "2022-09-21",
#         "vote_average": 6.818
#     },
#     {
#         "title": "One True Loves",
#         "tmdb_id": 846961,
#         "genres": [
#             "Romance",
#             "Comedy",
#             "Drama"
#         ],
#         "languages": [
#             "English",
#             "Spanish"
#         ],
#         "countries": [
#             "Czech Republic",
#             "United States of America"
#         ],
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "release_date": "2023-04-07",
#         "vote_average": 6.52
#     }
# ]

# %%
# Convert the results to a DataFrame
TMDB_Dataframe = pd.DataFrame(tmdb_movies_list)
TMDB_Dataframe.head(10)
# Out:
#                             title  tmdb_id  \
# 0          The Attachment Diaries   743040
# 1            You Can Live Forever   887580
# 2       A Tourist's Guide to Love   813726
# 3         Other People's Children   803694
# 4                  One True Loves   846961
# 5  The Lost Weekend: A Love Story   965042
# 6              A Thousand and One   855263
# 7              Your Place or Mine   703451
# 8    Love in the Time of Fentanyl   976653
# 9          The Attachment Diaries   743040
#
#                                genres                       languages  \
# 0  [Drama, Mystery, Thriller, Horror]                       [Spanish]
# 1                    [Drama, Romance]               [English, French]
# 2                   [Romance, Comedy]           [English, Vietnamese]
# 3                     [Drama, Comedy]               [French, English]
# 4            [Romance, Comedy, Drama]              [English, Spanish]
# 5                       [Documentary]                       [English]
# 6                      [Drama, Crime]  [English, Spanish, Portuguese]
# 7                   [Romance, Comedy]                       [English]
# 8                       [Documentary]                       [English]
# 9  [Drama, Mystery, Thriller, Horror]                       [Spanish]
#
#                                     countries  \
# 0                                 [Argentina]
# 1          [Canada, United States of America]
# 2                  [United States of America]
# 3                                    [France]
# 4  [Czech Republic, United States of America]
# 5                  [United States of America]
# 6                  [United States of America]
# 7                  [United States of America]
# 8          [Canada, United States of America]
# 9                                 [Argentina]
#
#                                             overview release_date  \
# 0  Argentina, 1970s. A desperate young woman goes...   2021-10-07
# 1  When Jaime, a gay teenager, is sent to live in...   2023-03-24
# 2  After an unexpected break up, a travel executi...   2023-04-21
# 3  Rachel loves her life, her students, her frien...   2022-09-21
# 4  Emma and Jesse are living the perfect life tog...   2023-04-07
# 5  May Pang lovingly recounts her life in rock & ...   2023-04-13
# 6  Struggling but unapologetically living on her ...   2023-03-31
# 7  When best friends and total opposites Debbie a...   2023-02-10
# 8  An intimate portrait of a community fighting t...   2023-02-03
# 9  Argentina, 1970s. A desperate young woman goes...   2021-10-07
#
#    vote_average
# 0         3.000
# 1         6.474
# 2         6.290
# 3         6.818
# 4         6.520
# 5         6.000
# 6         6.871
# 7         6.280
# 8         0.000
# 9         3.000

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
Merged_Dataframe = pd.merge(NYT_dataframe, TMDB_Dataframe, on='title', how='inner')
Merged_Dataframe.head(10)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
# 5  https://www.nytimes.com/2023/05/25/movies/the-...
# 6  https://www.nytimes.com/2023/05/25/movies/the-...
# 7  https://www.nytimes.com/2023/05/25/movies/the-...
# 8  https://www.nytimes.com/2023/05/25/movies/the-...
# 9  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
# 5  A gynecologist and her patient form a horrifyi...  The New York Times
# 6  A gynecologist and her patient form a horrifyi...  The New York Times
# 7  A gynecologist and her patient form a horrifyi...  The New York Times
# 8  A gynecologist and her patient form a horrifyi...  The New York Times
# 9  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  Movies, The Attachment Diaries (Movie), Diment...
# 1  Movies, The Attachment Diaries (Movie), Diment...
# 2  Movies, The Attachment Diaries (Movie), Diment...
# 3  Movies, The Attachment Diaries (Movie), Diment...
# 4  Movies, The Attachment Diaries (Movie), Diment...
# 5  Movies, The Attachment Diaries (Movie), Diment...
# 6  Movies, The Attachment Diaries (Movie), Diment...
# 7  Movies, The Attachment Diaries (Movie), Diment...
# 8  Movies, The Attachment Diaries (Movie), Diment...
# 9  Movies, The Attachment Diaries (Movie), Diment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
# 5  2023-05-25T11:00:03+0000         295
# 6  2023-05-25T11:00:03+0000         295
# 7  2023-05-25T11:00:03+0000         295
# 8  2023-05-25T11:00:03+0000         295
# 9  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
# 5  ‘The Attachment Diaries’ Review: Love, Sick            None
# 6  ‘The Attachment Diaries’ Review: Love, Sick            None
# 7  ‘The Attachment Diaries’ Review: Love, Sick            None
# 8  ‘The Attachment Diaries’ Review: Love, Sick            None
# 9  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ...  \
# 0                    None  The Attachment Diaries  ...
# 1                    None  The Attachment Diaries  ...
# 2                    None  The Attachment Diaries  ...
# 3                    None  The Attachment Diaries  ...
# 4                    None  The Attachment Diaries  ...
# 5                    None  The Attachment Diaries  ...
# 6                    None  The Attachment Diaries  ...
# 7                    None  The Attachment Diaries  ...
# 8                    None  The Attachment Diaries  ...
# 9                    None  The Attachment Diaries  ...
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Jeannette', 'middlename': None...                None
# 3  [{'firstname': 'Jeannette', 'middlename': None...                None
# 4  [{'firstname': 'Jeannette', 'middlename': None...                None
# 5  [{'firstname': 'Jeannette', 'middlename': None...                None
# 6  [{'firstname': 'Jeannette', 'middlename': None...                None
# 7  [{'firstname': 'Jeannette', 'middlename': None...                None
# 8  [{'firstname': 'Jeannette', 'middlename': None...                None
# 9  [{'firstname': 'Jeannette', 'middlename': None...                None
#
#                     title tmdb_id                              genres  \
# 0  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 1  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 2  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 3  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 4  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 5  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 6  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 7  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 8  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
# 9  The Attachment Diaries  743040  [Drama, Mystery, Thriller, Horror]
#
#    languages    countries                                           overview  \
# 0  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 1  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 2  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 3  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 4  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 5  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 6  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 7  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 8  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
# 9  [Spanish]  [Argentina]  Argentina, 1970s. A desperate young woman goes...
#
#   release_date vote_average
# 0   2021-10-07          3.0
# 1   2021-10-07          3.0
# 2   2021-10-07          3.0
# 3   2021-10-07          3.0
# 4   2021-10-07          3.0
# 5   2021-10-07          3.0
# 6   2021-10-07          3.0
# 7   2021-10-07          3.0
# 8   2021-10-07          3.0
# 9   2021-10-07          3.0
#
# [10 rows x 24 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'languages', 'countries']

# Create a list of characters to remove
chars_to_remove = ['[', ']', "'"]

# Create a copy of the original dataframe to modify
Merged_Dataframe_fixed = Merged_Dataframe.copy()

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    Merged_Dataframe_fixed[column] = Merged_Dataframe_fixed[column].astype(str)
    
    # Loop through characters to remove
    for char in chars_to_remove:
        Merged_Dataframe_fixed[column] = Merged_Dataframe_fixed[column].str.replace(char, '')
    
    # Remove any leading/trailing whitespace
    Merged_Dataframe_fixed[column] = Merged_Dataframe_fixed[column].str.strip()

# Display the fixed DataFrame in the nice chart format
Merged_Dataframe_fixed.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  Movies, The Attachment Diaries (Movie), Diment...
# 1  Movies, The Attachment Diaries (Movie), Diment...
# 2  Movies, The Attachment Diaries (Movie), Diment...
# 3  Movies, The Attachment Diaries (Movie), Diment...
# 4  Movies, The Attachment Diaries (Movie), Diment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ...  \
# 0                    None  The Attachment Diaries  ...
# 1                    None  The Attachment Diaries  ...
# 2                    None  The Attachment Diaries  ...
# 3                    None  The Attachment Diaries  ...
# 4                    None  The Attachment Diaries  ...
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Jeannette', 'middlename': None...                None
# 3  [{'firstname': 'Jeannette', 'middlename': None...                None
# 4  [{'firstname': 'Jeannette', 'middlename': None...                None
#
#                     title tmdb_id                            genres languages  \
# 0  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror   Spanish
# 1  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror   Spanish
# 2  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror   Spanish
# 3  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror   Spanish
# 4  The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror   Spanish
#
#    countries                                           overview release_date  \
# 0  Argentina  Argentina, 1970s. A desperate young woman goes...   2021-10-07
# 1  Argentina  Argentina, 1970s. A desperate young woman goes...   2021-10-07
# 2  Argentina  Argentina, 1970s. A desperate young woman goes...   2021-10-07
# 3  Argentina  Argentina, 1970s. A desperate young woman goes...   2021-10-07
# 4  Argentina  Argentina, 1970s. A desperate young woman goes...   2021-10-07
#
#   vote_average
# 0          3.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          3.0
#
# [5 rows x 24 columns]

# %%
# Drop "byline.person" column
Merged_Dataframe_fixed.drop('byline.person', axis=1, inplace=True)
Merged_Dataframe_fixed.head(10)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/25/movies/the-...
# 2  https://www.nytimes.com/2023/05/25/movies/the-...
# 3  https://www.nytimes.com/2023/05/25/movies/the-...
# 4  https://www.nytimes.com/2023/05/25/movies/the-...
# 5  https://www.nytimes.com/2023/05/25/movies/the-...
# 6  https://www.nytimes.com/2023/05/25/movies/the-...
# 7  https://www.nytimes.com/2023/05/25/movies/the-...
# 8  https://www.nytimes.com/2023/05/25/movies/the-...
# 9  https://www.nytimes.com/2023/05/25/movies/the-...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  A gynecologist and her patient form a horrifyi...  The New York Times
# 2  A gynecologist and her patient form a horrifyi...  The New York Times
# 3  A gynecologist and her patient form a horrifyi...  The New York Times
# 4  A gynecologist and her patient form a horrifyi...  The New York Times
# 5  A gynecologist and her patient form a horrifyi...  The New York Times
# 6  A gynecologist and her patient form a horrifyi...  The New York Times
# 7  A gynecologist and her patient form a horrifyi...  The New York Times
# 8  A gynecologist and her patient form a horrifyi...  The New York Times
# 9  A gynecologist and her patient form a horrifyi...  The New York Times
#
#                                             keywords  \
# 0  Movies, The Attachment Diaries (Movie), Diment...
# 1  Movies, The Attachment Diaries (Movie), Diment...
# 2  Movies, The Attachment Diaries (Movie), Diment...
# 3  Movies, The Attachment Diaries (Movie), Diment...
# 4  Movies, The Attachment Diaries (Movie), Diment...
# 5  Movies, The Attachment Diaries (Movie), Diment...
# 6  Movies, The Attachment Diaries (Movie), Diment...
# 7  Movies, The Attachment Diaries (Movie), Diment...
# 8  Movies, The Attachment Diaries (Movie), Diment...
# 9  Movies, The Attachment Diaries (Movie), Diment...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-25T11:00:03+0000         295
# 2  2023-05-25T11:00:03+0000         295
# 3  2023-05-25T11:00:03+0000         295
# 4  2023-05-25T11:00:03+0000         295
# 5  2023-05-25T11:00:03+0000         295
# 6  2023-05-25T11:00:03+0000         295
# 7  2023-05-25T11:00:03+0000         295
# 8  2023-05-25T11:00:03+0000         295
# 9  2023-05-25T11:00:03+0000         295
#
#                                  headline.main headline.kicker  \
# 0  ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘The Attachment Diaries’ Review: Love, Sick            None
# 2  ‘The Attachment Diaries’ Review: Love, Sick            None
# 3  ‘The Attachment Diaries’ Review: Love, Sick            None
# 4  ‘The Attachment Diaries’ Review: Love, Sick            None
# 5  ‘The Attachment Diaries’ Review: Love, Sick            None
# 6  ‘The Attachment Diaries’ Review: Love, Sick            None
# 7  ‘The Attachment Diaries’ Review: Love, Sick            None
# 8  ‘The Attachment Diaries’ Review: Love, Sick            None
# 9  ‘The Attachment Diaries’ Review: Love, Sick            None
#
#   headline.content_kicker headline.print_headline  ...  \
# 0                    None  The Attachment Diaries  ...
# 1                    None  The Attachment Diaries  ...
# 2                    None  The Attachment Diaries  ...
# 3                    None  The Attachment Diaries  ...
# 4                    None  The Attachment Diaries  ...
# 5                    None  The Attachment Diaries  ...
# 6                    None  The Attachment Diaries  ...
# 7                    None  The Attachment Diaries  ...
# 8                    None  The Attachment Diaries  ...
# 9                    None  The Attachment Diaries  ...
#
#           byline.original byline.organization                   title tmdb_id  \
# 0  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 1  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 2  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 3  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 4  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 5  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 6  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 7  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 8  By Jeannette Catsoulis                None  The Attachment Diaries  743040
# 9  By Jeannette Catsoulis                None  The Attachment Diaries  743040
#
#                              genres languages  countries  \
# 0  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 1  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 2  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 3  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 4  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 5  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 6  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 7  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 8  Drama, Mystery, Thriller, Horror   Spanish  Argentina
# 9  Drama, Mystery, Thriller, Horror   Spanish  Argentina
#
#                                             overview release_date vote_average
# 0  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 1  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 2  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 3  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 4  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 5  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 6  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 7  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 8  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
# 9  Argentina, 1970s. A desperate young woman goes...   2021-10-07          3.0
#
# [10 rows x 23 columns]

# %%
list_columns = [col for col in Merged_Dataframe.columns if Merged_Dataframe[col].apply(lambda x: isinstance(x, list)).any()]

# Convert list columns to strings
for col in list_columns:
    Merged_Dataframe[col] = Merged_Dataframe[col].apply(lambda x: ', '.join(map(str, x)) if isinstance(x, list) else x)

# Now remove duplicate rows
Merged_Dataframe = Merged_Dataframe.drop_duplicates()

# Reset the index
Merged_Dataframe = Merged_Dataframe.reset_index(drop=True)

# Display the DataFrame to verify
display(Merged_Dataframe.head())
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  Movies, The Attachment Diaries (Movie), Diment...
# 1  Movies, You Can Live Forever (Movie), Slutsky,...
# 2  Movies, Bracey, Luke (1989- ), Liu, Simu, Reid...
# 3  Documentary Films and Programs, The Lost Weeke...
# 4  Movies, A Thousand and One (Movie), Rockwell, ...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  ...  \
# 0                    None                   The Attachment Diaries  ...
# 1                    None                     You Can Live Forever  ...
# 2                    None                           One True Loves  ...
# 3                    None          The Lost Weekend:  A Love Story  ...
# 4                    None  An Unbending Will Meets a Shifting City  ...
#
#                                        byline.person byline.organization  \
# 0  {'firstname': 'Jeannette', 'middlename': None,...                None
# 1  {'firstname': 'Elisabeth', 'middlename': None,...                None
# 2  {'firstname': 'Brandon', 'middlename': None, '...                None
# 3  {'firstname': 'Glenn', 'middlename': None, 'la...                None
# 4  {'firstname': 'Manohla', 'middlename': None, '...                None
#
#                             title tmdb_id                            genres  \
# 0          The Attachment Diaries  743040  Drama, Mystery, Thriller, Horror
# 1            You Can Live Forever  887580                    Drama, Romance
# 2                  One True Loves  846961            Romance, Comedy, Drama
# 3  The Lost Weekend: A Love Story  965042                       Documentary
# 4              A Thousand and One  855263                      Drama, Crime
#
#                       languages                                 countries  \
# 0                       Spanish                                 Argentina
# 1               English, French          Canada, United States of America
# 2              English, Spanish  Czech Republic, United States of America
# 3                       English                  United States of America
# 4  English, Spanish, Portuguese                  United States of America
#
#                                             overview release_date vote_average
# 0  Argentina, 1970s. A desperate young woman goes...   2021-10-07        3.000
# 1  When Jaime, a gay teenager, is sent to live in...   2023-03-24        6.474
# 2  Emma and Jesse are living the perfect life tog...   2023-04-07        6.520
# 3  May Pang lovingly recounts her life in rock & ...   2023-04-13        6.000
# 4  Struggling but unapologetically living on her ...   2023-03-31        6.871
#
# [5 rows x 24 columns]

# %%
# Export data to CSV without the index

Merged_Dataframe.to_csv('collected_data.csv', index=False)
